# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv(r"alchohal_drinks.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       170 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
df.describe().T
# Out:
#                               count        mean         std  min   25%   50%  \
# beer_servings                 193.0  106.160622  101.143103  0.0  20.0  76.0
# spirit_servings               193.0   80.994819   88.284312  0.0   4.0  56.0
# wine_servings                 193.0   49.450777   79.697598  0.0   1.0   8.0
# total_litres_of_pure_alcohol  193.0    4.717098    3.773298  0.0   1.3   4.2
#
#                                 75%    max
# beer_servings                 188.0  376.0
# spirit_servings               128.0  438.0
# wine_servings                  59.0  370.0
# total_litres_of_pure_alcohol    7.2   14.4

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.columns=['country', 'beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol', 'continent']

# %%
df.country[0:193:10]
# Out:
# 0       Afghanistan
# 10       Azerbaijan
# 20          Bolivia
# 30         Cambodia
# 40     Cook Islands
# 50         Dominica
# 60          Finland
# 70           Guinea
# 80             Iraq
# 90           Kuwait
# 100      Madagascar
# 110      Micronesia
# 120     Netherlands
# 130          Panama
# 140         Romania
# 150         Senegal
# 160           Spain
# 170       Macedonia
# 180         Ukraine
# 190           Yemen
# Name: country, dtype: object

# %% [raw]
# maximum  beer_serving country

# %%
df[['country', 'beer_servings']].max()
# Out:
# country          Zimbabwe
# beer_servings         376
# dtype: object

# %% [raw]
# datatypes of variables

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.country.describe()
# Out:
# count           193
# unique          193
# top       Lithuania
# freq              1
# Name: country, dtype: object

# %%
df.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
df[df["continent"] == 'EU']
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %%
df[df["beer_servings"] > 250]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 8         Australia            261               72            212
# 9           Austria            279               75            191
# 16          Belgium            295               84            212
# 17           Belize            263              114              8
# 45   Czech Republic            361              170            134
# 60          Finland            263              133             97
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 81          Ireland            313              118            165
# 93           Latvia            281              216             62
# 98        Lithuania            343              244             56
# 117         Namibia            376                3              1
# 120     Netherlands            251               88            190
# ...

# %%
df[(df['continent']!= 'EU') & (df['beer_servings'] > 250)]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 8    Australia            261               72            212
# 17      Belize            263              114              8
# 62       Gabon            347               98             59
# 117    Namibia            376                3              1
# 129      Palau            306               63             23
# 130     Panama            285              104             18
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol continent
# 8                            10.4        OC
# 17                            6.8       NaN
# 62                            8.9        AF
# 117                           6.8        AF
# 129                           6.9        OC
# 130                           7.2       NaN
# 188                           7.7        SA

# %%
df[(df['wine_servings'] + df['beer_servings'])  ==0]
# Out:
#               country  beer_servings  spirit_servings  wine_servings  \
# 0         Afghanistan              0                0              0
# 13         Bangladesh              0                0              0
# 46        North Korea              0                0              0
# 79               Iran              0                0              0
# 90             Kuwait              0                0              0
# 97              Libya              0                0              0
# 103          Maldives              0                0              0
# 106  Marshall Islands              0                0              0
# 107        Mauritania              0                0              0
# 111            Monaco              0                0              0
# 128          Pakistan              0                0              0
# 147        San Marino              0                0              0
# 149      Saudi Arabia              0                5              0
# ...

# %%
df.sort_values(by = 'total_litres_of_pure_alcohol').tail()
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# 45  Czech Republic            361              170            134
# 68         Grenada            199              438             28
# 3          Andorra            245              138            312
# 98       Lithuania            343              244             56
# 15         Belarus            142              373             42
#
#     total_litres_of_pure_alcohol continent
# 45                          11.8        EU
# 68                          11.9       NaN
# 3                           12.4        EU
# 98                          12.9        EU
# 15                          14.4        EU
